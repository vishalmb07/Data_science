# %%
import pandas as pd

# %%
f=pd.read_csv('fifa_eda.csv')

# %%
f[:2]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
f.head(2)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
f.isna().sum().sort_values(ascending=False)
# Out:
# Contract Valid Until        289
# Value                       252
# Club                        241
# International Reputation     48
# Skill Moves                  48
# ID                            0
# Name                          0
# Potential                     0
# Age                           0
# Nationality                   0
# Preferred Foot                0
# Wage                          0
# Overall                       0
# Position                      0
# Joined                        0
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
f.isnull().sum().sort_values(ascending=False)
# Out:
# Contract Valid Until        289
# Value                       252
# Club                        241
# International Reputation     48
# Skill Moves                  48
# ID                            0
# Name                          0
# Potential                     0
# Age                           0
# Nationality                   0
# Preferred Foot                0
# Wage                          0
# Overall                       0
# Position                      0
# Joined                        0
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
f['Club'].shape
# Out:
# (18207,)

# %%
f['Club'].value_counts()
# Out:
# Club
# RC Celta               33
# Everton                33
# Valencia CF            33
# Borussia Dortmund      33
# TSG 1899 Hoffenheim    33
#                        ..
# Botafogo               20
# Vitória                20
# Sligo Rovers           19
# Limerick FC            19
# Derry City             18
# Name: count, Length: 651, dtype: int64

# %%
f['Club'].fillna('Unknown class',inplace=True)

# %%
f['Club'].sort_values(ascending=False)
# Out:
# 8798            Śląsk Wrocław
# 10524           Śląsk Wrocław
# 17567           Śląsk Wrocław
# 7910            Śląsk Wrocław
# 7228            Śląsk Wrocław
#                  ...
# 8337      SSV Jahn Regensburg
# 11861     SSV Jahn Regensburg
# 11244     SSV Jahn Regensburg
# 4587      SSV Jahn Regensburg
# 6184      SSV Jahn Regensburg
# Name: Club, Length: 18207, dtype: object

# %%
f.isna().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                          0
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
f.dropna()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
v_avg=f['Value'].mean().round(2)
print(v_avg)
# Out:
# 2444.53

# %%
f['Preferred Foot']
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object

# %%
f['Preferred Foot'].map({'Left':0,'Right':1})
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 18202    1
# 18203    1
# 18204    1
# 18205    1
# 18206    1
# Name: Preferred Foot, Length: 18207, dtype: int64

# %%
f['Preferred Foot']=f['Preferred Foot'].apply(lambda x: 0 if x=='Left' else 1)

# %%
f[f['Preferred Foot']==1]
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# 5      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage  Preferred Foot  \
# ...

# %%
f.groupby('Preferred Foot').get_group(1)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# 5      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage  Preferred Foot  \
# ...

# %%
f.groupby('Preferred Foot').get_group(0)
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 13     168542           David Silva   32                Spain       90
# 15     211110             P. Dybala   24            Argentina       89
# 17     194765          A. Griezmann   27               France       89
# 19     192119           T. Courtois   26              Belgium       89
# ...       ...                   ...  ...                  ...      ...
# 18172  243636            C. Hawkins   18              England       48
# 18175  243649             E. Clarke   19              England       48
# 18191  245570  J. Norville-Williams   18              England       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
#
#        Potential              Club     Value   Wage  Preferred Foot  \
# ...

# %%
f.groupby('Nationality').get_group('Brazil')
# Out:
#            ID              Name  Age Nationality  Overall  Potential  \
# 2      190871         Neymar Jr   26      Brazil       92         93
# 27     200145          Casemiro   26      Brazil       88         90
# 32     189242          Coutinho   26      Brazil       88         89
# 35     176676           Marcelo   30      Brazil       88         88
# 39     164240      Thiago Silva   33      Brazil       88         88
# ...       ...               ...  ...         ...      ...        ...
# 17059  243750  Gianluca Zanette   21      Brazil       55         66
# 17446  235949         Strefezza   21      Brazil       54         62
# 17588  244311     Lucas Ribeiro   19      Brazil       53         71
# 17611  241268   Felipe Ferreyra   20      Brazil       53         67
# 18170  246447   Nicolas Firmino   17      Brazil       48         70
#
#                          Club     Value   Wage  Preferred Foot  \
# 2         Paris Saint-Germain  118500.0  290.0               1
# ...

# %%
f['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
f['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
f.groupby('Position').get_group('LW')
# Out:
#            ID                 Name  Age Nationality  Overall  Potential  \
# 2      190871            Neymar Jr   26      Brazil       92         93
# 29     198219           L. Insigne   27       Italy       88         88
# 30     197781                 Isco   26       Spain       88         91
# 32     189242             Coutinho   26      Brazil       88         89
# 55     222492              L. Sané   22     Germany       86         92
# ...       ...                  ...  ...         ...      ...        ...
# 17727  242941  M. Bustgaard Larsen   18      Norway       53         70
# 17740  240650         R. Najjarine   18   Australia       52         71
# 17899  244494         F. Delaveris   17      Norway       51         66
# 17938  245861         L. Cavallini   18       Italy       51         69
# 18038  243790         Zhen'ao Wang   18    China PR       50         62
#
#                       Club     Value   Wage  Preferred Foot  \
# ...

# %%
f.groupby(['Position','Nationality']).get_group(('LW',"Brazil"))
# Out:
#            ID             Name  Age Nationality  Overall  Potential  \
# 2      190871        Neymar Jr   26      Brazil       92         93
# 32     189242         Coutinho   26      Brazil       88         89
# 1143   238794  Vinícius Júnior   17      Brazil       77         92
# 1709   230468     José Mirazar   34      Brazil       75         75
# 2656   204823  Nildo Petrolina   32      Brazil       73         73
# 2832   229218      Pedro Rocha   23      Brazil       73         79
# 2898   239482           Galeno   20      Brazil       73         84
# 3006   192165         Paulinho   32      Brazil       73         73
# 3926   199412             Sebá   26      Brazil       72         73
# 4863   232219          Bismark   24      Brazil       70         72
# 5400   235706   Murilo Freitas   22      Brazil       70         80
# 6285   240046      João Victor   24      Brazil       69         72
# 6307   230581         Niltinho   24      Brazil       69         72
# ...

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage  Preferred Foot  \
# ...

# %%
f.groupby(['Nationality','Club']).get_group(('Argentina','FC Barcelona'))
# Out:
#        ID      Name  Age Nationality  Overall  Potential          Club  \
# 0  158023  L. Messi   31   Argentina       94         94  FC Barcelona
#
#       Value   Wage  Preferred Foot  International Reputation  Skill Moves  \
# 0  110500.0  565.0               0                       5.0          4.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause
# 0       RF    2004           2021-01-01  5.583333   159.0        226500.0

# %%
# f.groupby(['Nationality','Club']).get_group(('FC Barcelona','Argentina'))

# %%
import warnings
warnings.filterwarnings('ignore')

f.groupby(['Nationality','Club'])['Age'].agg([max,min,'mean'])
# Out:
#                                 max  min  mean
# Nationality Club
# Afghanistan Notts County         21   21  21.0
#             Philadelphia Union   23   23  23.0
#             SV Meppen            26   26  26.0
#             Walsall              20   20  20.0
# Albania     AC Ajaccio           22   22  22.0
# ...                             ...  ...   ...
# Zimbabwe    Le Havre AC          22   22  22.0
#             Nottingham Forest    26   26  26.0
#             Orlando Pirates      24   22  23.0
#             RSC Anderlecht       28   28  28.0
#             Sparta Praha         32   32  32.0
#
# [5155 rows x 3 columns]

# %%
f.groupby('Nationality')['Age'].agg([max,min,'mean'])
# Out:
#              max  min       mean
# Nationality
# Afghanistan   26   20  22.500000
# Albania       34   18  24.025000
# Algeria       35   19  27.050000
# Andorra       28   28  28.000000
# Angola        34   19  25.866667
# ...          ...  ...        ...
# Uzbekistan    30   29  29.500000
# Venezuela     34   18  24.313433
# Wales         37   17  24.736434
# Zambia        29   18  22.222222
# Zimbabwe      34   22  26.846154
#
# [164 rows x 3 columns]
