# %%
# PANDAS Continueeee...

# %%
# https://github.com/hakimyameen/Datasets/blob/main/fifa_eda.csv

# %%
import pandas as pd

# %%
f = pd.read_csv('fifa_eda.csv')
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
path='https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv'
path
# Out:
# 'https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv'

# %%
c=pd.read_csv(path)
c
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
f.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
f.head(50)
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %%
f[0:3]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
f[100:104]
# Out:
#          ID           Name  Age Nationality  Overall  Potential  \
# 100  179844    Diego Costa   29       Spain       85         85
# 101  178518  R. Nainggolan   30     Belgium       85         85
# 102  171919          Naldo   35      Brazil       85         85
# 103  170890     B. Matuidi   31      France       85         85
#
#                 Club    Value   Wage Preferred Foot  International Reputation  \
# 100  Atlético Madrid  38500.0  100.0          Right                       4.0
# 101            Inter  35500.0  105.0          Right                       3.0
# 102    FC Schalke 04   9000.0   38.0          Right                       3.0
# 103         Juventus  26000.0  145.0           Left                       3.0
#
#      Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 100          2.0       LS    2018           2021-01-01  6.166667   190.0
# 101          3.0      CAM    2018           2022-01-01  5.750000   170.0
# ...

# %%
f[30000:40000]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Nationality, Overall, Potential, Club, Value, Wage, Preferred Foot, International Reputation, Skill Moves, Position, Joined, Contract Valid Until, Height, Weight, Release Clause]
# Index: []

# %%
f[-3:]
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
f[-3:-1]
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0

# %%
f.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
f.tail(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
f[-5:]   #for last 5 records
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
f.sample(5)
# Out:
#            ID        Name  Age Nationality  Overall  Potential  \
# 12989  231402   M. Penney   20     England       63         79
# 1323   193869         Gil   31      Brazil       76         76
# 4469   202148  A. Khalili   26      Sweden       71         74
# 2187   215103     E. Puch   31       Chile       74         74
# 8606   213724       Bicho   22       Spain       67         75
#
#                              Club   Value  Wage Preferred Foot  \
# 12989         Sheffield Wednesday   725.0   4.0           Left
# 1323   Shandong Luneng TaiShan FC  5000.0  18.0          Right
# 4469                 Kasimpaşa SK  2900.0  10.0          Right
# 2187                    Querétaro  4900.0  26.0          Right
# 8606       Deportivo de La Coruña  1100.0   3.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# 12989                       1.0          2.0       LB    2015
# 1323                        2.0          2.0      LCB    2016
# ...

# %%
f.sample()
# Out:
#            ID       Name  Age  Nationality  Overall  Potential  \
# 11412  217190  A. Flores   27  El Salvador       64         64
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 11412  Portland Timbers  475.0   2.0           Left                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 11412          3.0       CM    2018           2019-01-01  5.583333   148.0
#
#        Release Clause
# 11412           713.0

# %%
f.loc[:,:]
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.loc[:2,]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
f.loc[0:2,]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
f.loc[:2,'Name':'Nationality']
# Out:
#                 Name  Age Nationality
# 0           L. Messi   31   Argentina
# 1  Cristiano Ronaldo   33    Portugal
# 2          Neymar Jr   26      Brazil

# %%
f.loc[0:10:3,'Name':'Overall']
# Out:
#         Name  Age Nationality  Overall
# 0   L. Messi   31   Argentina       94
# 3     De Gea   27       Spain       91
# 6  L. Modrić   32     Croatia       91
# 9   J. Oblak   25    Slovenia       90

# %%
f.loc[0:10:3,'Name':'Overall':2]
# Out:
#         Name Nationality
# 0   L. Messi   Argentina
# 3     De Gea       Spain
# 6  L. Modrić     Croatia
# 9   J. Oblak    Slovenia

# %%
f.loc[0:10:2,'Name':'Club':2]
# Out:
#               Name Nationality  Potential
# 0         L. Messi   Argentina         94
# 2        Neymar Jr      Brazil         93
# 4     K. De Bruyne     Belgium         92
# 6        L. Modrić     Croatia         91
# 8     Sergio Ramos       Spain         91
# 10  R. Lewandowski      Poland         90

# %%
s='python'

# %%
s[0]
# Out:
# 'p'

# %%
s[-1]
# Out:
# 'n'

# %%
s[:3]
# Out:
# 'pyt'

# %%
s[-3:-1]
# Out:
# 'ho'

# %%
s[-3:]
# Out:
# 'hon'

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.loc[50:55]
# Out:
#         ID           Name  Age Nationality  Overall  Potential  \
# 50  175943     D. Mertens   31     Belgium       87         87
# 51  172871  J. Vertonghen   31     Belgium       87         87
# 52  171877      M. Hamšík   30    Slovakia       87         87
# 53  168651     I. Rakitić   30     Croatia       87         87
# 54  152729          Piqué   31       Spain       87         87
# 55  222492        L. Sané   22     Germany       86         92
#
#                  Club    Value   Wage Preferred Foot  \
# 50             Napoli  45000.0  135.0          Right
# 51  Tottenham Hotspur  34000.0  155.0           Left
# 52             Napoli  46500.0  125.0          Right
# 53       FC Barcelona  46500.0  260.0          Right
# 54       FC Barcelona  34000.0  240.0          Right
# 55    Manchester City  61000.0  195.0           Left
#
#     International Reputation  Skill Moves Position  Joined  \
# 50                       3.0          4.0       RF    2013
# ...

# %%
f.loc[50:55:2]
# Out:
#         ID        Name  Age Nationality  Overall  Potential          Club  \
# 50  175943  D. Mertens   31     Belgium       87         87        Napoli
# 52  171877   M. Hamšík   30    Slovakia       87         87        Napoli
# 54  152729       Piqué   31       Spain       87         87  FC Barcelona
#
#       Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 50  45000.0  135.0          Right                       3.0          4.0
# 52  46500.0  125.0          Right                       3.0          3.0
# 54  34000.0  240.0          Right                       4.0          2.0
#
#    Position  Joined Contract Valid Until    Height  Weight  Release Clause
# 50       RF    2013           2020-01-01  5.583333   134.0         76500.0
# 52      LCM    2007           2020-01-01  6.000000   174.0         79100.0
# 54      RCB    2008           2022-01-01  6.333333   187.0         69700.0

# %%
f.loc[50:55:2,'ID':'Overall']
# Out:
#         ID        Name  Age Nationality  Overall
# 50  175943  D. Mertens   31     Belgium       87
# 52  171877   M. Hamšík   30    Slovakia       87
# 54  152729       Piqué   31       Spain       87

# %%
f.loc[50:55:2,'ID':'Overall':2]
# Out:
#         ID  Age  Overall
# 50  175943   31       87
# 52  171877   30       87
# 54  152729   31       87

# %%
f.loc[50:55:2,'ID':'Overall':3]
# Out:
#         ID Nationality
# 50  175943     Belgium
# 52  171877    Slovakia
# 54  152729       Spain

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.loc[50:60:2,::-1]   #for reverse the column
# Out:
#     Release Clause  Weight    Height Contract Valid Until  Joined Position  \
# 50         76500.0   134.0  5.583333           2020-01-01    2013       RF
# 52         79100.0   174.0  6.000000           2020-01-01    2007      LCM
# 54         69700.0   187.0  6.333333           2022-01-01    2008      RCB
# 56        114500.0   141.0  5.666667           2022-01-01    2017       RW
# 58        102700.0   152.0  5.750000           2023-01-01    2016       LM
# 60        108800.0   152.0  5.583333           2023-01-01    2015       RW
#
#     Skill Moves  International Reputation Preferred Foot   Wage    Value  \
# 50          4.0                       3.0          Right  135.0  45000.0
# 52          3.0                       3.0          Right  125.0  46500.0
# 54          2.0                       4.0          Right  240.0  34000.0
# 56          4.0                       2.0           Left  180.0  59500.0
# 58          4.0                       3.0          Right  195.0  52000.0
# ...

# %%
f.loc[50:60:2,['Club','Age','Name']]
# Out:
#                Club  Age            Name
# 50           Napoli   31      D. Mertens
# 52           Napoli   30       M. Hamšík
# 54     FC Barcelona   31           Piqué
# 56  Manchester City   23  Bernardo Silva
# 58        Liverpool   26         S. Mané
# 60  Manchester City   23     R. Sterling

# %%
f.loc[50:60:2,('Club','Age','Name')]
# Out:
#                Club  Age            Name
# 50           Napoli   31      D. Mertens
# 52           Napoli   30       M. Hamšík
# 54     FC Barcelona   31           Piqué
# 56  Manchester City   23  Bernardo Silva
# 58        Liverpool   26         S. Mané
# 60  Manchester City   23     R. Sterling

# %%
f.loc[50:60:2,['Club','Age','NamE']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_673/2517587253.py in <cell line: 0>()
# ----> 1 f.loc[50:60:2,['Club','Age','NamE']]
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1375             return self._multi_take(tup)
#    1376
# -> 1377         return self._getitem_tuple_same_dim(tup)
#    1378
#    1379     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
f.set_index('ID')   #donot use this
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 158023            L. Messi   31   Argentina       94         94
# 20801    Cristiano Ronaldo   33    Portugal       94         94
# 190871           Neymar Jr   26      Brazil       92         93
# 193080              De Gea   27       Spain       91         93
# 192985        K. De Bruyne   27     Belgium       91         92
# ...                    ...  ...         ...      ...        ...
# 238813        J. Lundstram   19     England       47         65
# 243165  N. Christoffersson   19      Sweden       47         63
# 241638           B. Worman   16     England       47         67
# 246268      D. Walker-Rice   17     England       47         66
# 246269           G. Nugent   16     England       46         66
#
#                        Club     Value   Wage Preferred Foot  \
# ID
# 158023         FC Barcelona  110500.0  565.0           Left
# 20801              Juventus   77000.0  405.0          Right
# ...
