# %%
import pandas as pd

# %%
import pandas as pd

# %%
f=pd.read_csv('fifa_eda.csv')
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
f.tail()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18202   Crewe Alexandra   60.0   1.0          Right                       1.0
# 18203    Trelleborgs FF   60.0   1.0          Right                       1.0
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
# ...

# %%
f.sample(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 9893   212986  Michel Douglas   26      Brazil       66         68
# 14211  176737   B. Ziegenbein   32     Germany       61         61
# 6135   199305       M. Wittek   29     Germany       69         69
#
#                         Club  Value  Wage Preferred Foot  \
# 9893                 CD Aves  800.0   4.0           Left
# 14211     FC Energie Cottbus  200.0   1.0          Right
# 6135   1. FC Heidenheim 1846  825.0   7.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 9893                        1.0          3.0       ST    2018
# 14211                       1.0          3.0       RM    2016
# 6135                        1.0          2.0       CB    2012
#
#       Contract Valid Until    Height  Weight  Release Clause
# 9893            2023-01-01  6.083333   183.0          1700.0
# 14211           2019-01-01  5.750000   159.0           290.0
# ...

# %%
f['Club']
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2        Paris Saint-Germain
# 3          Manchester United
# 4            Manchester City
#                 ...
# 18202        Crewe Alexandra
# 18203         Trelleborgs FF
# 18204       Cambridge United
# 18205        Tranmere Rovers
# 18206        Tranmere Rovers
# Name: Club, Length: 18207, dtype: object

# %%
path='https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv'
path
# Out:
# 'https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv'

# %%
g=pd.read_csv(path)
g
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
g.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
f[:2]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
f.loc[:7:2,'Name':'Wage']
# Out:
#            Name  Age Nationality  Overall  Potential                 Club  \
# 0      L. Messi   31   Argentina       94         94         FC Barcelona
# 2     Neymar Jr   26      Brazil       92         93  Paris Saint-Germain
# 4  K. De Bruyne   27     Belgium       91         92      Manchester City
# 6     L. Modrić   32     Croatia       91         91          Real Madrid
#
#       Value   Wage
# 0  110500.0  565.0
# 2  118500.0  290.0
# 4  102000.0  355.0
# 6   67000.0  420.0

# %%
f.loc[:7:2,'Name':'Wage':2]
# Out:
#            Name Nationality  Potential     Value
# 0      L. Messi   Argentina         94  110500.0
# 2     Neymar Jr      Brazil         93  118500.0
# 4  K. De Bruyne     Belgium         92  102000.0
# 6     L. Modrić     Croatia         91   67000.0

# %%
f.loc[:7:2,['Name','Wage','Overall','Value']]
# Out:
#            Name   Wage  Overall     Value
# 0      L. Messi  565.0       94  110500.0
# 2     Neymar Jr  290.0       92  118500.0
# 4  K. De Bruyne  355.0       91  102000.0
# 6     L. Modrić  420.0       91   67000.0

# %%
f.iloc[:,:]
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.iloc[10:13,1:4]
# Out:
#               Name  Age Nationality
# 10  R. Lewandowski   29      Poland
# 11        T. Kroos   28     Germany
# 12        D. Godín   32     Uruguay

# %%
f.iloc[10:13,1:4:2]
# Out:
#               Name Nationality
# 10  R. Lewandowski      Poland
# 11        T. Kroos     Germany
# 12        D. Godín     Uruguay

# %%
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
list(enumerate(f.columns))
# Out:
# [(0, 'ID'),
#  (1, 'Name'),
#  (2, 'Age'),
#  (3, 'Nationality'),
#  (4, 'Overall'),
#  (5, 'Potential'),
#  (6, 'Club'),
#  (7, 'Value'),
#  (8, 'Wage'),
#  (9, 'Preferred Foot'),
#  (10, 'International Reputation'),
#  (11, 'Skill Moves'),
#  (12, 'Position'),
#  (13, 'Joined'),
#  (14, 'Contract Valid Until'),
#  (15, 'Height'),
#  (16, 'Weight'),
#  (17, 'Release Clause')]

# %%
dict([(1,100),(2,200)])
# Out:
# {1: 100, 2: 200}

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
f.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
f.loc[0:2,['Joined','Club','Name','Nationality']]
# Out:
#    Joined                 Club               Name Nationality
# 0    2004         FC Barcelona           L. Messi   Argentina
# 1    2018             Juventus  Cristiano Ronaldo    Portugal
# 2    2017  Paris Saint-Germain          Neymar Jr      Brazil

# %%
f.iloc[:2 ,[13,6,1,3]]
# Out:
#    Joined          Club               Name Nationality
# 0    2004  FC Barcelona           L. Messi   Argentina
# 1    2018      Juventus  Cristiano Ronaldo    Portugal

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
# select first 5 rows and skip last columns

# %%
f.loc[:4,'ID':'Weight']
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
f.iloc[:5,:17]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
f.iloc[:5,:-1]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
# select last 5 rows and age, name club, value

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
f.iloc[-5: ,[2,1,6,7]]
# Out:
#        Age                Name              Club  Value
# 18202   19        J. Lundstram   Crewe Alexandra   60.0
# 18203   19  N. Christoffersson    Trelleborgs FF   60.0
# 18204   16           B. Worman  Cambridge United   60.0
# 18205   17      D. Walker-Rice   Tranmere Rovers   60.0
# 18206   16           G. Nugent   Tranmere Rovers   60.0

# %%
f.tail().iloc[ : ,[2,1,6,7]]
# Out:
#        Age                Name              Club  Value
# 18202   19        J. Lundstram   Crewe Alexandra   60.0
# 18203   19  N. Christoffersson    Trelleborgs FF   60.0
# 18204   16           B. Worman  Cambridge United   60.0
# 18205   17      D. Walker-Rice   Tranmere Rovers   60.0
# 18206   16           G. Nugent   Tranmere Rovers   60.0

# %%
f.loc[-5:,['Age','Name','Club','Value']]  #negative indexing not working on rows
# Out:
#        Age                Name                 Club     Value
# 0       31            L. Messi         FC Barcelona  110500.0
# 1       33   Cristiano Ronaldo             Juventus   77000.0
# 2       26           Neymar Jr  Paris Saint-Germain  118500.0
# 3       27              De Gea    Manchester United   72000.0
# 4       27        K. De Bruyne      Manchester City  102000.0
# ...    ...                 ...                  ...       ...
# 18202   19        J. Lundstram      Crewe Alexandra      60.0
# 18203   19  N. Christoffersson       Trelleborgs FF      60.0
# 18204   16           B. Worman     Cambridge United      60.0
# 18205   17      D. Walker-Rice      Tranmere Rovers      60.0
# 18206   16           G. Nugent      Tranmere Rovers      60.0
#
# [18207 rows x 4 columns]

# %%
f.tail().iloc[:,[2,1,6,7]]
# Out:
#        Age                Name              Club  Value
# 18202   19        J. Lundstram   Crewe Alexandra   60.0
# 18203   19  N. Christoffersson    Trelleborgs FF   60.0
# 18204   16           B. Worman  Cambridge United   60.0
# 18205   17      D. Walker-Rice   Tranmere Rovers   60.0
# 18206   16           G. Nugent   Tranmere Rovers   60.0

# %%
f.iloc[-5: ,:][['Age','Name','Club','Value']]
# Out:
#        Age                Name              Club  Value
# 18202   19        J. Lundstram   Crewe Alexandra   60.0
# 18203   19  N. Christoffersson    Trelleborgs FF   60.0
# 18204   16           B. Worman  Cambridge United   60.0
# 18205   17      D. Walker-Rice   Tranmere Rovers   60.0
# 18206   16           G. Nugent   Tranmere Rovers   60.0

# %%
f['Contract Valid Until']
# Out:
# 0        2021-01-01
# 1        2022-01-01
# 2        2022-01-01
# 3        2020-01-01
# 4        2023-01-01
#             ...
# 18202    2019-01-01
# 18203    2020-01-01
# 18204    2021-01-01
# 18205    2019-01-01
# 18206    2019-01-01
# Name: Contract Valid Until, Length: 18207, dtype: object

# %%
f['Age']
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
f['Age'].ndim
# Out:
# 1

# %%
f.ndim
# Out:
# 2

# %%
f.Name
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
f.Age
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.Preferred Foot
# Out:
#   File "/tmp/ipykernel_1986/2742187089.py", line 1
#     f.Preferred Foot
#                 ^
# SyntaxError: invalid syntax

# %%
f.rename(columns={'Preferred Foot':'Preferred_Foot'})
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred_Foot  \
# ...

# %%
f.rename(columns={'Preferred Foot':'Preferred_Foot','Skill Moves':'SK_M'})
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred_Foot  \
# ...

# %%
f
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
f.rename(columns={'Preferred Foot':'Preferred_Foot','Skill Moves':'SK_M'},inplace=True)

# %%
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred_Foot', 'International Reputation', 'SK_M',
#        'Position', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
f.columns.

# %%
f.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred_Foot               object
# International Reputation    float64
# SK_M                        float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
f.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred_Foot', 'International Reputation', 'SK_M',
#        'Position', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
f.columns.str.replace(' ','_')
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred_Foot', 'International_Reputation', 'SK_M',
#        'Position', 'Joined', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release_Clause'],
#       dtype='object')

# %%
f.columns=f.columns.str.replace(' ','_')

# %%
f.columns=f.columns.str.lower().str.replace(' ','_')

# %%
f.columns
# Out:
# Index(['id', 'name', 'age', 'nationality', 'overall', 'potential', 'club',
#        'value', 'wage', 'preferred_foot', 'international_reputation', 'sk_m',
#        'position', 'joined', 'contract_valid_until', 'height', 'weight',
#        'release_clause'],
#       dtype='object')

# %%
f.isna()
# Out:
#           ID   Name    Age  Nationality  Overall  Potential   Club  Value  \
# 0      False  False  False        False    False      False  False  False
# 1      False  False  False        False    False      False  False  False
# 2      False  False  False        False    False      False  False  False
# 3      False  False  False        False    False      False  False  False
# 4      False  False  False        False    False      False  False  False
# ...      ...    ...    ...          ...      ...        ...    ...    ...
# 18202  False  False  False        False    False      False  False  False
# 18203  False  False  False        False    False      False  False  False
# 18204  False  False  False        False    False      False  False  False
# 18205  False  False  False        False    False      False  False  False
# 18206  False  False  False        False    False      False  False  False
#
#         Wage  Preferred_Foot  International_Reputation   SK_M  Position  \
# ...

# %%
f.isnull()
# Out:
#           ID   Name    Age  Nationality  Overall  Potential   Club  Value  \
# 0      False  False  False        False    False      False  False  False
# 1      False  False  False        False    False      False  False  False
# 2      False  False  False        False    False      False  False  False
# 3      False  False  False        False    False      False  False  False
# 4      False  False  False        False    False      False  False  False
# ...      ...    ...    ...          ...      ...        ...    ...    ...
# 18202  False  False  False        False    False      False  False  False
# 18203  False  False  False        False    False      False  False  False
# 18204  False  False  False        False    False      False  False  False
# 18205  False  False  False        False    False      False  False  False
# 18206  False  False  False        False    False      False  False  False
#
#         Wage  Preferred_Foot  International_Reputation   SK_M  Position  \
# ...

# %%
f.isna().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred_Foot                0
# International_Reputation     48
# SK_M                         48
# Position                      0
# Joined                        0
# Contract_Valid_Until        289
# Height                        0
# Weight                        0
# Release_Clause                0
# dtype: int64
